# %% [markdown]
# <a href="https://colab.research.google.com/github/valixonov04/small_projects/blob/main/Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/reklama_sales.csv")

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.corrwith(df.Sales)
# Out:
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Sales        1.000000
# dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,3,1)
plt.scatter(data=df , y="Newspaper",x="Sales")
plt.title("Newspaper")
plt.subplot(1,3,2)
plt.scatter(data=df , y="TV",x="Sales")
plt.title("TV")
plt.subplot(1,3,3)
plt.scatter(data=df , y="Radio",x="Sales")
plt.title("Radio")
plt.show()

# %%
#chizmadan ko'rinib turibdiki TV da berilgan reklamalar ancha sotuvlarga tasir qilgan
from sklearn.model_selection import train_test_split
train_set,test_set = train_test_split(df, random_state=42,train_size=0.9)

# %%
train_set
# Out:
#         TV  Radio  Newspaper  Sales
# 124  229.5   32.3       74.2   19.7
# 16    67.8   36.6      114.0   12.5
# 148   38.0   40.3       11.9   10.9
# 93   250.9   36.5       72.3   22.2
# 65    69.0    9.3        0.9   11.3
# ..     ...    ...        ...    ...
# 106   25.0   11.0       29.7    7.2
# 14   204.1   32.9       46.0   19.0
# 92   217.7   33.5       59.0   19.4
# 179  165.6   10.0       17.6   17.6
# 102  280.2   10.1       21.4   19.8
#
# [180 rows x 4 columns]

# %%
test_set
# Out:
#         TV  Radio  Newspaper  Sales
# 95   163.3   31.6       52.9   16.9
# 15   195.4   47.7       52.9   22.4
# 30   292.9   28.3       43.2   21.4
# 158   11.7   36.9       45.2    7.3
# 128  220.3   49.0        3.2   24.7
# 115   75.1   35.0       52.7   12.6
# 69   216.8   43.9       27.2   22.3
# 170   50.0   11.6       18.4    8.4
# 174  222.4    3.4       13.1   16.5
# 45   175.1   22.5       31.5   16.1
# 66    31.5   24.6        2.2   11.0
# 182   56.2    5.7       29.7    8.7
# 165  234.5    3.4       84.8   16.9
# 78     5.4   29.9        9.4    5.3
# 186  139.5    2.1       26.6   10.3
# 177  170.2    7.8       35.2   16.7
# 56     7.3   28.1       41.4    5.5
# 152  197.6   23.3       14.2   16.6
# 82    75.3   20.3       32.5   11.3
# 68   237.4   27.5       11.0   18.9

# %%
X = train_set.drop("Sales", axis=1)
y = train_set.Sales

# %%
X_num = np.asanyarray(X)
y_num = np.asanyarray(y)

# %%
X_num
# Out:
# array([[229.5,  32.3,  74.2],
#        [ 67.8,  36.6, 114. ],
#        [ 38. ,  40.3,  11.9],
#        [250.9,  36.5,  72.3],
#        [ 69. ,   9.3,   0.9],
#        [ 53.5,   2. ,  21.4],
#        [213.5,  43. ,  33.8],
#        [139.3,  14.5,  10.2],
#        [ 87.2,  11.8,  25.9],
#        [  8.4,  27.2,   2.1],
#        [199.8,   2.6,  21.2],
#        [ 69.2,  20.5,  18.3],
#        [198.9,  49.4,  60. ],
#        [ 16.9,  43.7,  89.4],
#        [280.7,  13.9,  37. ],
#        [238.2,  34.3,   5.3],
#        [ 48.3,  47. ,   8.5],
#        [273.7,  28.9,  59.7],
#        [117.2,  14.7,   5.4],
#        [ 27.5,   1.6,  20.7],
#        [116. ,   7.7,  23.1],
#        [177. ,   9.3,   6.4],
#        [ 43.1,  26.7,  35.1],
#        [ 62.3,  12.6,  18.3],
#        [224. ,   2.4,  15.6],
#        [ 38.2,   3.7,  13.8],
#        [ 70.6,  16. ,  40.8],
#        [147.3,  23.9,  19.1],
#        [104.6,   5.7,  34.4],
#        [ 76.3,  27.5,  16. ],
#        [ 78.2,  46.8,  34.5],
# ...

# %%
from sklearn.linear_model import LinearRegression
LR_model = LinearRegression()
LR_model.fit(X_num,y_num)
# Out:
# LinearRegression()

# %%
X_test_num = np.asanyarray(test_set.drop("Sales",axis=1))
y_test_num = np.asanyarray(test_set.Sales)

# %%
predict_model = LR_model.predict(X_test_num)
predict_model
# Out:
# array([16.95475874, 20.34957323, 23.59840218,  9.28586421, 21.7101576 ,
#        12.53596246, 21.05310377,  8.68469708, 17.14801369, 16.60338211,
#         8.98522655,  8.43906824, 17.97485925,  8.1376273 , 12.56437833,
#        14.83238467,  8.1318945 , 17.86068584, 10.98316263, 20.43770208])

# %%
y_test_num
# Out:
# array([16.9, 22.4, 21.4,  7.3, 24.7, 12.6, 22.3,  8.4, 16.5, 16.1, 11. ,
#         8.7, 16.9,  5.3, 10.3, 16.7,  5.5, 16.6, 11.3, 18.9])

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test_num,predict_model)
print("MSE: ",mse )
# Out:
# MSE:  2.8583804713199905

# %%
mse = mean_squared_error(y_test_num,predict_model)
print("RMSE: ",np.sqrt(mse))
# Out:
# RMSE:  1.6906745610317766
